# %% [markdown]
# <a href="https://colab.research.google.com/github/sava990/Learning/blob/main/sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr


data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 12, 22, 25, 64]

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %%
def quick_sort_produk(arr, kriteria, urutan='naik'):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]


    if urutan == 'naik':
        left = [x for x in arr if x[kriteria] < pivot[kriteria]]
        middle = [x for x in arr if x[kriteria] == pivot[kriteria]]
        right = [x for x in arr if x[kriteria] > pivot[kriteria]]
    elif urutan == 'turun':
        left = [x for x in arr if x[kriteria] > pivot[kriteria]]
        middle = [x for x in arr if x[kriteria] == pivot[kriteria]]
        right = [x for x in arr if x[kriteria] < pivot[kriteria]]


    return quick_sort_produk(left, kriteria, urutan) + middle + quick_sort_produk(right, kriteria, urutan)


daftar_produk = [
    {"nama": "Sepatu Sneakers", "harga": 250000, "rating": 4.8},
    {"nama": "Kaos Polos", "harga": 50000, "rating": 4.5},
    {"nama": "Jaket Denim", "harga": 350000, "rating": 4.9},
    {"nama": "Topi Baseball", "harga": 35000, "rating": 4.2},
    {"nama": "Tas Ransel", "harga": 150000, "rating": 4.7}
]

print("--- Data Produk Belum Terurut ---")
for p in daftar_produk:
    print(f"{p['nama']} - Rp{p['harga']} (Rating: {p['rating']})")

produk_termurah = quick_sort_produk(daftar_produk.copy(), kriteria='harga', urutan='naik')

print("\n--- Hasil Filter: Harga Terendah ke Tertinggi ---")
for p in produk_termurah:
    print(f"{p['nama']} - Rp{p['harga']} (Rating: {p['rating']})")

produk_terbaik = quick_sort_produk(daftar_produk.copy(), kriteria='rating', urutan='turun')

print("\n--- Hasil Filter: Rating Pelanggan Tertinggi ---")
for p in produk_terbaik:
    print(f"{p['nama']} - Rp{p['harga']} (Rating: {p['rating']})")
# Out:
# --- Data Produk Belum Terurut ---
# Sepatu Sneakers - Rp250000 (Rating: 4.8)
# Kaos Polos - Rp50000 (Rating: 4.5)
# Jaket Denim - Rp350000 (Rating: 4.9)
# Topi Baseball - Rp35000 (Rating: 4.2)
# Tas Ransel - Rp150000 (Rating: 4.7)
#
# --- Hasil Filter: Harga Terendah ke Tertinggi ---
# Topi Baseball - Rp35000 (Rating: 4.2)
# Kaos Polos - Rp50000 (Rating: 4.5)
# Tas Ransel - Rp150000 (Rating: 4.7)
# Sepatu Sneakers - Rp250000 (Rating: 4.8)
# Jaket Denim - Rp350000 (Rating: 4.9)
#
# --- Hasil Filter: Rating Pelanggan Tertinggi ---
# Jaket Denim - Rp350000 (Rating: 4.9)
# Sepatu Sneakers - Rp250000 (Rating: 4.8)
# Tas Ransel - Rp150000 (Rating: 4.7)
# Kaos Polos - Rp50000 (Rating: 4.5)
# Topi Baseball - Rp35000 (Rating: 4.2)
