# %% [markdown]
# <a href="https://colab.research.google.com/github/sava990/Learning/blob/main/Queue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
queue = []

waktu_mulai = time.perf_counter()
queue.append('a')
queue.append('i')
queue.append('u')
queue.append('e')
queue.append('o')

print('Initial queue')
print(queue)

print('\nElements dequeued from queue:')
print(queue.pop(0))
print(queue.pop(0))
print(queue.pop(0))

print('\nQueue after removing elements')
print(queue)

waktu_selesai = time.perf_counter()
durasi = waktu_selesai - waktu_mulai
print(durasi)
# Out:
# Initial queue
# ['a', 'i', 'u', 'e', 'o']
#
# Elements dequeued from queue:
# a
# i
# u
#
# Queue after removing elements
# ['e', 'o']
# 0.0016018750002331217

# %%
from collections import deque

queue = deque()
waktu_mulai = time.perf_counter()

queue.append('a')
queue.append('i')
queue.append('u')
queue.append('e')
queue.append('o')

print('Initial queue:')
print(queue)

print("\nElements dequeued from the queue")
print(queue.popleft())
print(queue.popleft())
print(queue.popleft())

print("\nQueue after removing elements")
print(queue)

waktu_selesai = time.perf_counter()
durasi = waktu_selesai - waktu_mulai
print(durasi)
# Out:
# Initial queue:
# deque(['a', 'i', 'u', 'e', 'o'])
#
# Elements dequeued from the queue
# a
# i
# u
#
# Queue after removing elements
# deque(['e', 'o'])
# 0.0005922250002186047

# %%
from queue import Queue

qu = Queue(maxsize=5)

print(qu.qsize())

qu.put('a')
qu.put('i')
qu.put('u')
qu.put('e')
qu.put('o')

print("Full: ", qu.full())
print("Size: ", qu.qsize())

print("\nElements dequeued from the queue")
print(qu.get())
print(qu.get())
print(qu.get())

print("\nEmpty: ", qu.empty())
print("Full: ", qu.full())
# Out:
# 0
# Full:  True
# Size:  5
#
# Elements dequeued from the queue
# a
# i
# u
#
# Empty:  False
# Full:  False

# %%
class Queue:
    def __init__(self):
        self.queue = list()

    def addtoqu(self,dataval):

        if dataval not in self.queue:
            self.queue.insert(0,dataval)
            return True
        return False


    def removefromq(self):
        if len(self.queue)>0:
            return self.queue.pop()
        return ("No elements in Queue!")

    def size(self):
        return len(self.queue)

TheQueue = Queue()
print(TheQueue.addtoqu("Jan"))
print(TheQueue.addtoqu("Feb"))
print(TheQueue.addtoqu("March"))
print(TheQueue.addtoqu("April"))
print(TheQueue.size())
print(TheQueue.removefromq())
print(TheQueue.removefromq())
print(TheQueue.size())
# Out:
# True
# True
# True
# True
# 4
# Jan
# Feb
# 2
