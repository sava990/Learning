# %% [markdown]
# <a href="https://colab.research.google.com/github/sava990/Learning/blob/main/hashing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class SimpleHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        self.table[index] = value

    def search(self, key):
        index = self.hash_function(key)
        return self.table[index]

# Contoh penggunaan
ht = SimpleHashTable(10)
ht.insert("apel", 100)
ht.insert("pisang", 200)

print("Nilai untuk 'apel':", ht.search("apel"))
print("Nilai untuk 'pisang':", ht.search("pisang"))
# Out:
# Nilai untuk 'apel': 100
# Nilai untuk 'pisang': 200

# %%
class LinearProbingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        original_index = index

        while self.table[index] is not None:
            if self.table[index][0] == key:
                break
            index = (index + 1) % self.size
            if index == original_index:
                raise Exception("Hash table penuh")

        self.table[index] = (key, value)

    def search(self, key):
        index = self.hash_function(key)
        original_index = index

        while self.table[index] is not None:
            if self.table[index][0] == key:
                return self.table[index][1]
            index = (index + 1) % self.size
            if index == original_index:
                break
        return None

# Contoh penggunaan
ht = LinearProbingHashTable(5)
ht.insert("apel", 100)
ht.insert("pisang", 200)
ht.insert("melon", 300)

print("Nilai untuk 'apel':", ht.search("apel"))
print("Nilai untuk 'melon':", ht.search("melon"))
# Out:
# Nilai untuk 'apel': 100
# Nilai untuk 'melon': 300

# %%
class ChainingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for _ in range(size)]

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        for i, (k, v) in enumerate(self.table[index]):
            if k == key:
                self.table[index][i] = (key, value)
                return
        self.table[index].append((key, value))

    def search(self, key):
        index = self.hash_function(key)
        for k, v in self.table[index]:
            if k == key:
                return v
        return None

# Contoh penggunaan
ht = ChainingHashTable(5)
ht.insert("apel", 100)
ht.insert("pisang", 200)
ht.insert("melon", 300)

print("Nilai untuk 'apel':", ht.search("apel"))
print("Nilai untuk 'melon':", ht.search("melon"))
# Out:
# Nilai untuk 'apel': 100
# Nilai untuk 'melon': 300

# %%
class LinearProbingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        original_index = index

        while self.table[index] is not None:
            if self.table[index][0] == key:
                break
            index = (index + 1) % self.size
            if index == original_index:
                raise Exception("Hash table penuh")

        self.table[index] = (key, value)

# Instruksi a: Buat objek LinearProbingHashTable dengan ukuran tabel 5.
ht_linear = LinearProbingHashTable(5)

# Instruksi b: Masukkan pasangan key-value
ht_linear.insert("A", 10)
ht_linear.insert("B", 20)
ht_linear.insert("C", 30)
ht_linear.insert("D", 40)
ht_linear.insert("E", 50)

# Instruksi c: Cetak isi array self.table setelah semua data dimasukkan.
print("Isi tabel Linear Probing:")
print(ht_linear.table)
# Out:
# Isi tabel Linear Probing:
# [('A', 10), ('D', 40), ('C', 30), ('B', 20), ('E', 50)]

# %%
class ChainingHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for _ in range(size)]

    def hash_function(self, key):
        return hash(key) % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        for i, (k, v) in enumerate(self.table[index]):
            if k == key:
                self.table[index][i] = (key, value)
                return
        self.table[index].append((key, value))

# Instruksi a: Gunakan ukuran tabel 3.
ht_chaining = ChainingHashTable(3)

# Instruksi b: Masukkan key-value
ht_chaining.insert("apel", 100)
ht_chaining.insert("melon", 200)
ht_chaining.insert("lemon", 300)
ht_chaining.insert("pisang", 400)

# Instruksi c: Cetak isi tabel dan tampilkan semua data yang disimpan di setiap slot.
print("\nIsi tabel Chaining secara keseluruhan:")
print(ht_chaining.table)

print("\nDetail data yang disimpan di setiap slot:")
for i in range(len(ht_chaining.table)):
    print(f"Slot {i}: {ht_chaining.table[i]}")
# Out:
# Isi tabel Chaining secara keseluruhan:
# [[('apel', 100), ('melon', 200)], [], [('lemon', 300), ('pisang', 400)]]
#
# Detail data yang disimpan di setiap slot:
# Slot 0: [('apel', 100), ('melon', 200)]
# Slot 1: []
# Slot 2: [('lemon', 300), ('pisang', 400)]
